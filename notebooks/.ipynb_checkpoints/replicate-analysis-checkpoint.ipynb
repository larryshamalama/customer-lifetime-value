# %%
import numpy as np
import pandas as pd

import arviz as az
import pymc as pm
import aesara.tensor as at

from lifetimes.datasets import load_cdnow_summary
from lifetimes import BetaGeoFitter

# %%
df = load_cdnow_summary(index_col=0)
df.head(10)
# Out:
#     frequency  recency      T
# ID
# 1           2    30.43  38.86
# 2           1     1.71  38.86
# 3           0     0.00  38.86
# 4           0     0.00  38.86
# 5           0     0.00  38.86
# 6           7    29.43  38.86
# 7           1     5.00  38.86
# 8           0     0.00  38.86
# 9           2    35.71  38.86
# 10          0     0.00  38.86

# %%
n = df.shape[0]
x = df["frequency"].to_numpy()
t_x = df["recency"].to_numpy()
T = df["T"].to_numpy()

x_zero = (x > 0).astype(int)

# %%
bgf = BetaGeoFitter()
bgf.fit(frequency=x, recency=t_x, T=T)

bgf.summary
# Out:
#            coef  se(coef)  lower 95% bound  upper 95% bound
# r      0.242593  0.012557         0.217981         0.267205
# alpha  4.413532  0.378221         3.672218         5.154846
# a      0.792886  0.185719         0.428877         1.156895
# b      2.425752  0.705345         1.043276         3.808229

# %% [markdown]
# ### Full Bayesian Model

# %%
with pm.Model() as model_full:
    
    a = pm.HalfNormal(name="a", sigma=10)
    b = pm.HalfNormal(name="b", sigma=10)
    
    alpha = pm.HalfNormal(name="alpha", sigma=10)
    r = pm.HalfNormal(name="r", sigma=10)
    
    lam = pm.Gamma(name="lam", alpha=r, beta=alpha, shape=n)
    p = pm.Beta(name="p", alpha=a, beta=b, shape=n)
    
    def logp(x, t_x, T, x_zero):
        log_term_a = x*at.log(1 - p) + x*at.log(lam) - t_x*lam
        term_b_1 = -lam*(T - t_x)
        term_b_2 = at.log(p) - at.log(1 - p)
        log_term_b = at.switch(
            x_zero,
            at.logsumexp(term_b_1, term_b_2),
            term_b_1,
        )
        
        return at.sum(log_term_a) + at.sum(log_term_b)
    
    likelihood = pm.DensityDist(
        name="likelihood",
        logp=logp,
        observed={"x": x, "t_x": t_x, "T": T, "x_zero": x_zero}
    )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <module>
#      16     log_term_b = at.switch(
#      17         x_zero,
#      18         at.logsumexp(term_b_1, term_b_2),
#      19         term_b_1,
#      20     )
#      22     return at.sum(log_term_a) + at.sum(log_term_b)
# ---> 24 likelihood = pm.DensityDist(
#      25     name="likelihood",
#      26     logp=logp,
#      27     observed={"x": x, "t_x": t_x, "T": T, "x_zero": x_zero}
#      28 )
#
# File ~/opt/anaconda3/envs/pymc-dev-py39/lib/python3.9/site-packages/pymc/distributions/distribution.py:877, in DensityDist.__new__(cls, name, logp, logcdf, random, get_moment, ndim_supp, ndims_params, dtype, *dist_params, **kwargs)
#     874     return get_moment(rv, size, *dist_params)
#     876 cls.rv_op = rv_op
# --> 877 return super().__new__(cls, name, *dist_params, **kwargs)
#
# File ~/opt/anaconda3/envs/pymc-dev-py39/lib/python3.9/site-packages/pymc/distributions/distribution.py:268, in Distribution.__new__(cls, name, rng, dims, initval, observed, total_size, transform, *args, **kwargs)
#     264     rng = model.next_rng()
#     266 # Create the RV and process dims and observed to determine
#     267 # a shape by which the created RV may need to be resized.
# --> 268 rv_out, dims, observed, resize_shape = _make_rv_and_resize_shape(
#     269     cls=cls, dims=dims, model=model, observed=observed, args=args, rng=rng, **kwargs
#     270 )
#     272 if resize_shape:
#     273     # A batch size was specified through `dims`, or implied by `observed`.
#     274     rv_out = change_rv_size(rv_var=rv_out, new_size=resize_shape, expand=True)
#
# File ~/opt/anaconda3/envs/pymc-dev-py39/lib/python3.9/site-packages/pymc/distributions/distribution.py:182, in _make_rv_and_resize_shape(cls, dims, model, observed, args, **kwargs)
#     180         dims = (*dims[:-1], *[None] * ndim_actual)[:ndim_actual]
#     181 elif observed is not None:
# --> 182     resize_shape, observed = resize_from_observed(observed, ndim_actual)
#     183 return rv_out, dims, observed, resize_shape
#
# File ~/opt/anaconda3/envs/pymc-dev-py39/lib/python3.9/site-packages/pymc/distributions/shape_utils.py:562, in resize_from_observed(observed, ndim_implied)
#     545 """Determines a potential resize shape from observations.
#     546
#     547 Parameters
#    (...)
#     559     Observations as numpy array or `Variable`.
#     560 """
#     561 if not hasattr(observed, "shape"):
# --> 562     observed = pandas_to_array(observed)
#     563 ndim_resize = observed.ndim - ndim_implied
#     564 resize_shape = tuple(observed.shape[d] for d in range(ndim_resize))
#
# File ~/opt/anaconda3/envs/pymc-dev-py39/lib/python3.9/site-packages/pymc/aesaraf.py:140, in pandas_to_array(data)
#     137         return floatX(ret)
#     138 # needed for uses of this function other than with pm.Data:
#     139 else:
# --> 140     return floatX(ret)
#
# File ~/opt/anaconda3/envs/pymc-dev-py39/lib/python3.9/site-packages/pymc/aesaraf.py:440, in floatX(X)
#     436 """
#     437 Convert an Aesara tensor or numpy array to aesara.config.floatX type.
#     438 """
#     439 try:
# --> 440     return X.astype(aesara.config.floatX)
#     441 except AttributeError:
#     442     # Scalar passed
#     443     return np.asarray(X, dtype=aesara.config.floatX)
#
# TypeError: float() argument must be a string or a number, not 'dict'
